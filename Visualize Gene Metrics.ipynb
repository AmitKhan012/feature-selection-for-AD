# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv("dataset/Gene_Metrics_Info.csv")
col = df["Gene Symbol"]
# df.drop("Gene Symbol", axis =1, inplace = True)
df2 = df.drop("Gene Symbol", axis =1)
df2 =df2.T.rename(columns = col)

# %%
df2
# Out:
#                          HIST1H3G  TNFAIP8L1   OTOP2  CTAGE6 || CTAGE15  \
# Mean Standard Deviation    0.2377     2.4977  0.3734             0.3436
# Mean Max                   2.5467     7.0980  2.8182             2.4837
# Mean Mean                  2.2895     5.3318  2.5542             2.2407
# Mean Median                2.2987     5.3318  2.5542             2.2407
# Mean CV                    0.1036     0.4695  0.1455             0.1534
#
#                          LINC01098  \
# Mean Standard Deviation     0.1168
# Mean Max                    2.4627
# Mean Mean                   2.3801
# Mean Median                 2.3801
# Mean CV                     0.0490
#
#                          CGB || CGB1 || CGB2 || CGB5 || CGB7 || CGB8  FAM86C1  \
# Mean Standard Deviation                                       0.2153   0.1391
# Mean Max                                                      2.7183   5.0677
# Mean Mean                                                     2.4485   4.9362
# ...

# %%
def plot_graph(column_stats):
    column_stats = column_stats.T

    # Create a stacked bar chart
    fig, ax = plt.subplots(figsize=(12, 6))

    column_stats.plot(kind='bar', stacked=True, ax=ax)
    plt.xticks(rotation=90)

    plt.show()

# %%
for i in range(len(df2)):
  plot_graph(df2.iloc[i:i+1])

# %%
# creating a density plot for mean stadard deviation of 12500 gene

# %%
df
# Out:
#               Gene Symbol  Mean Standard Deviation  Mean Max  Mean Mean  \
# 0                HIST1H3G                   0.2377    2.5467     2.2895
# 1               TNFAIP8L1                   2.4977    7.0980     5.3318
# 2                   OTOP2                   0.3734    2.8182     2.5542
# 3       CTAGE6 || CTAGE15                   0.3436    2.4837     2.2407
# 4               LINC01098                   0.1168    2.4627     2.3801
# ...                   ...                      ...       ...        ...
# 12495     ENSG00000236066                   0.1545    4.3436     4.2343
# 12496     ENSG00000249642                   0.4238    2.4342     2.1346
# 12497     ENSG00000229192                   0.3325    2.3322     2.0971
# 12498     ENSG00000250971                   0.2652    2.8285     2.6410
# 12499  RNA18S5 || RNA45S5                   2.0730   11.8386     9.5043
#
#        Mean Median  Mean CV
# 0           2.2987   0.1036
# 1           5.3318   0.4695
# ...

# %%
sns.kdeplot(df["Mean Standard Deviation"], shade=True)
# Out:
# C:\Users\Amit\AppData\Local\Temp\ipykernel_10036\1192933245.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["Mean Standard Deviation"], shade=True)
# <Axes: xlabel='Mean Standard Deviation', ylabel='Density'>

# %%
sns.kdeplot(df["Mean CV"], shade=True)
# Out:
# C:\Users\Amit\AppData\Local\Temp\ipykernel_10036\1801507477.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["Mean CV"], shade=True)
# <Axes: xlabel='Mean CV', ylabel='Density'>
